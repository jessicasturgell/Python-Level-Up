# %% [markdown]
# ### The Anatomy Of A Dataframe
# ![Dataframe Anatomy](../images/dataframe-anatomy.png)

# %% [markdown]
# ### pandas is a python library for working with dataframes
# - get familiar with using the [API reference](https://pandas.pydata.org/pandas-docs/stable/reference/index.html#api), which gives information about the many objects, functions and methods for working with dataframes and series

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Let's explore these pandas methods, attributes, and accessors
#  - read_csv( )
#  - .shape
#  - .head( )
#  - .tail( )
#  - .columns
#  - .drop( )
#  - .rename( )
#  - .loc[]
#  - .isin( )
#  - .iloc[ ]
#  - [[ ]]

# %% [markdown]
# ### Read in the schools data, a CSV file, and examine the shape, head, and tail

# %%
schools = pd.read_csv('../data/schools_clean.csv')
schools.head(2)
# Out:
#                level                     name  zipcode  grade_k  grade_1  \
# 0  Elementary School  A. Z. Kelley Elementary    37013    153.0    145.0
# 1  Elementary School    Alex Green Elementary    37189     42.0     50.0
#
#    grade_2  grade_3  grade_4  grade_5  grade_6  ...  hisp  p_islander  white  \
# 0    149.0    180.0    184.0      NaN      NaN  ...   206         1.0  212.0
# 1     44.0     38.0     24.0      NaN      NaN  ...    29         1.0   21.0
#
#    male  female  econ_disadv  disabled  limited_eng        lat        lng
# 0   431     421          261      75.0        298.0  36.021817 -86.658848
# 1   115     119          153      21.0         25.0  36.252961 -86.832229
#
# [2 rows x 29 columns]

# %%
schools.tail(2)
# Out:
#              level                         name  zipcode  grade_k  grade_1  \
# 165  Middle School  William Henry Oliver Middle    37211      NaN      NaN
# 166  Middle School                Wright Middle    37211      NaN      NaN
#
#      grade_2  grade_3  grade_4  grade_5  grade_6  ...  hisp  p_islander  \
# 165      NaN      NaN      NaN    231.0    271.0  ...   158         3.0
# 166      NaN      NaN      NaN    188.0    216.0  ...   534         1.0
#
#      white  male  female  econ_disadv  disabled  limited_eng        lat  \
# 165  437.0   487     498          252     112.0        231.0  36.020174
# 166  104.0   443     367          400      75.0        536.0  36.100109
#
#            lng
# 165 -86.712207
# 166 -86.734133
#
# [2 rows x 29 columns]

# %%
schools.shape
# Out:
# (167, 29)

# %% [markdown]
# #### the `columns` attribute shows the column names for the DataFrame

# %%
schools.columns
# Out:
# Index(['level', 'name', 'zipcode', 'grade_k', 'grade_1', 'grade_2', 'grade_3',
#        'grade_4', 'grade_5', 'grade_6', 'grade_7', 'grade_8', 'grade_9',
#        'grade_10', 'grade_11', 'grade_12', 'native_amer', 'asian', 'black',
#        'hisp', 'p_islander', 'white', 'male', 'female', 'econ_disadv',
#        'disabled', 'limited_eng', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# #### The `iloc[ ]` accessor gets the specified rows and columns by their _index_ values

# %%
first_five = schools.iloc[0:5, 0:2]

# %%
first_five
# Out:
#                level                       name
# 0  Elementary School    A. Z. Kelley Elementary
# 1  Elementary School      Alex Green Elementary
# 2  Elementary School           Amqui Elementary
# 3  Elementary School  Andrew Jackson Elementary
# 4        High School        Antioch High School

# %% [markdown]
# #### The `loc[ ]` accessor gets the specified rows and columns by their _names_

# %%
middle_schools = schools.loc[schools['level'] == 'Middle School'].head()
middle_schools.shape
# Out:
# (5, 29)

# %%
middle_schools.head()
# Out:
#             level                                name  zipcode  grade_k  \
# 5   Middle School                      Antioch Middle    37013      NaN
# 6   Middle School                       Apollo Middle    37013      NaN
# 7   Middle School                     Bellevue Middle    37221      NaN
# 21  Middle School  Creswell Middle School of the Arts    37218      NaN
# 23  Middle School                        Croft Middle    37211      NaN
#
#     grade_1  grade_2  grade_3  grade_4  grade_5  grade_6  ...  hisp  \
# 5       NaN      NaN      NaN      NaN     97.0    251.0  ...   407
# 6       NaN      NaN      NaN      NaN    178.0    214.0  ...   428
# 7       NaN      NaN      NaN      NaN    144.0    175.0  ...    85
# 21      NaN      NaN      NaN      NaN     88.0    105.0  ...    11
# 23      NaN      NaN      NaN      NaN    174.0    214.0  ...   379
#
#     p_islander  white  male  female  econ_disadv  disabled  limited_eng  \
# 5          3.0  104.0   413     407          391     105.0        415.0
# 6          NaN  137.0   421     414          340      97.0        417.0
# 7          1.0  300.0   328     303          211      93.0         67.0
# 21         NaN   30.0   138     224          163      41.0          4.0
# 23         1.0  207.0   387     363          262      80.0        332.0
#
#           lat        lng
# 5   36.055379 -86.671830
# 6   36.066878 -86.664070
# 7   36.070749 -86.934820
# 21  36.196063 -86.837539
# 23  36.087475 -86.734148
#
# [5 rows x 29 columns]

# %%
econ_disadv_over_200 = schools.loc[schools.econ_disadv > 200]
econ_disadv_over_200.shape
# Out:
# (78, 29)

# %%
econ_disadv_over_200.head()
# Out:
#                level                     name  zipcode  grade_k  grade_1  \
# 0  Elementary School  A. Z. Kelley Elementary    37013    153.0    145.0
# 2  Elementary School         Amqui Elementary    37115     84.0     93.0
# 4        High School      Antioch High School    37013      NaN      NaN
# 5      Middle School           Antioch Middle    37013      NaN      NaN
# 6      Middle School            Apollo Middle    37013      NaN      NaN
#
#    grade_2  grade_3  grade_4  grade_5  grade_6  ...  hisp  p_islander  white  \
# 0    149.0    180.0    184.0      NaN      NaN  ...   206         1.0  212.0
# 2     77.0     87.0     84.0      NaN      NaN  ...   209         1.0   57.0
# 4      NaN      NaN      NaN      NaN      NaN  ...   806         1.0  387.0
# 5      NaN      NaN      NaN     97.0    251.0  ...   407         3.0  104.0
# 6      NaN      NaN      NaN    178.0    214.0  ...   428         NaN  137.0
#
#    male  female  econ_disadv  disabled  limited_eng        lat        lng
# 0   431     421          261      75.0        298.0  36.021817 -86.658848
# 2   223     235          246      51.0        143.0  36.273766 -86.703832
# 4  1026     889          622     185.0        634.0  36.046675 -86.599418
# 5   413     407          391     105.0        415.0  36.055379 -86.671830
# 6   421     414          340      97.0        417.0  36.066878 -86.664070
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Use the isin method to reference an external data structure

# %%
my_list = [37201, 37203]
downtown_schools = schools.loc[schools.zipcode.isin(my_list)]
downtown_schools.shape
# Out:
# (6, 29)

# %%
downtown_schools.head()
# Out:
#                 level                          name  zipcode  grade_k  \
# 14  Elementary School    Carter-Lawrence Elementary    37203     38.0
# 37  Elementary School      Fall-Hamilton Elementary    37203     49.0
# 55      Middle School                   Head Middle    37203      NaN
# 62        High School                Hume-Fogg High    37203      NaN
# 98        High School  Martin Luther King Jr School    37203      NaN
#
#     grade_1  grade_2  grade_3  grade_4  grade_5  grade_6  ...  hisp  \
# 14     46.0     50.0     51.0     58.0      NaN      NaN  ...    20
# 37     56.0     60.0     49.0     37.0      NaN      NaN  ...    69
# 55      NaN      NaN      NaN      NaN    170.0    179.0  ...    31
# 62      NaN      NaN      NaN      NaN      NaN      NaN  ...    68
# 98      NaN      NaN      NaN      NaN      NaN      NaN  ...   111
#
#     p_islander  white  male  female  econ_disadv  disabled  limited_eng  \
# 14         2.0   25.0   135     128          159      25.0         24.0
# 37         1.0   47.0   172     140          170      63.0         43.0
# 55         NaN  133.0   286     265          124      31.0         43.0
# 62         NaN  534.0   346     555           60      27.0          8.0
# 98         1.0  539.0   635     633          129      24.0         23.0
#
#           lat        lng
# 14  36.143653 -86.785853
# 37  36.133472 -86.766206
# 55  36.158605 -86.804406
# 62  36.159525 -86.781536
# 98  36.161676 -86.800474
#
# [5 rows x 29 columns]

# %%
school_and_type = schools[['name', 'level']]
school_and_type.head(2)
# Out:
#                       name              level
# 0  A. Z. Kelley Elementary  Elementary School
# 1    Alex Green Elementary  Elementary School

# %% [markdown]
# #### Drop columns from a DataFrame with the `.drop( )` method; be sure to specify `columns = ` and pass a list of columns to the method

# %%
schools.columns
# Out:
# Index(['level', 'name', 'zipcode', 'grade_k', 'grade_1', 'grade_2', 'grade_3',
#        'grade_4', 'grade_5', 'grade_6', 'grade_7', 'grade_8', 'grade_9',
#        'grade_10', 'grade_11', 'grade_12', 'native_amer', 'asian', 'black',
#        'hisp', 'p_islander', 'white', 'male', 'female', 'econ_disadv',
#        'disabled', 'limited_eng', 'lat', 'lng'],
#       dtype='object')

# %%
school_and_gender_counts = schools.drop(columns = ['native_amer', 'asian', 'black', 'hisp', 'p_islander', 'white', 
                                              'econ_disadv', 'disabled', 'limited_eng', 'lat', 'lng'])

# %%
school_and_gender_counts.columns
# Out:
# Index(['level', 'name', 'zipcode', 'grade_k', 'grade_1', 'grade_2', 'grade_3',
#        'grade_4', 'grade_5', 'grade_6', 'grade_7', 'grade_8', 'grade_9',
#        'grade_10', 'grade_11', 'grade_12', 'male', 'female'],
#       dtype='object')

# %% [markdown]
# #### If the column list is short and you are feeling lazy, you can assign new column names (as a list _with every column in the right order_ ) to the columns attribute

# %%
school_and_type.columns
# Out:
# Index(['name', 'level'], dtype='object')

# %%
school_and_type.columns = ['school', 'type']
school_and_type.head()
# Out:
#                       school               type
# 0    A. Z. Kelley Elementary  Elementary School
# 1      Alex Green Elementary  Elementary School
# 2           Amqui Elementary  Elementary School
# 3  Andrew Jackson Elementary  Elementary School
# 4        Antioch High School        High School

# %% [markdown]
# #### If you only want to change the name of a subset of columns, use the df.rename() function

# %%
school_and_gender_counts = school_and_gender_counts.rename(columns = {'level': 'type', 'name': 'school'})
school_and_gender_counts.head()
# Out:
#                 type                     school  zipcode  grade_k  grade_1  \
# 0  Elementary School    A. Z. Kelley Elementary    37013    153.0    145.0
# 1  Elementary School      Alex Green Elementary    37189     42.0     50.0
# 2  Elementary School           Amqui Elementary    37115     84.0     93.0
# 3  Elementary School  Andrew Jackson Elementary    37138     95.0     93.0
# 4        High School        Antioch High School    37013      NaN      NaN
#
#    grade_2  grade_3  grade_4  grade_5  grade_6  grade_7  grade_8  grade_9  \
# 0    149.0    180.0    184.0      NaN      NaN      NaN      NaN      NaN
# 1     44.0     38.0     24.0      NaN      NaN      NaN      NaN      NaN
# 2     77.0     87.0     84.0      NaN      NaN      NaN      NaN      NaN
# 3     85.0     88.0    103.0      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN    499.0
#
#    grade_10  grade_11  grade_12  male  female
# 0       NaN       NaN       NaN   431     421
# 1       NaN       NaN       NaN   115     119
# 2       NaN       NaN       NaN   223     235
# 3       NaN       NaN       NaN   258     238
# 4     486.0     482.0     448.0  1026     889

# %% [markdown]
# # End of Instruction

# %% [markdown]
# ### Starting with the schools dataframe filter out just the High Schools and create a new datafrom called "high_schools".

# %%
high_schools = schools.loc[schools.level == 'High School']

# %%
high_schools.head()
# Out:
#           level                    name  zipcode  grade_k  grade_1  grade_2  \
# 4   High School     Antioch High School    37013      NaN      NaN      NaN
# 13  High School  Cane Ridge High School    37013      NaN      NaN      NaN
# 35  High School   East Nashville School    37206      NaN      NaN      NaN
# 40  High School   Glencliff High School    37211      NaN      NaN      NaN
# 59  High School          Hillsboro High    37215      NaN      NaN      NaN
#
#     grade_3  grade_4  grade_5  grade_6  ...  hisp  p_islander  white  male  \
# 4       NaN      NaN      NaN      NaN  ...   806         1.0  387.0  1026
# 13      NaN      NaN      NaN      NaN  ...   655         3.0  313.0   980
# 35      NaN      NaN      NaN      NaN  ...    13         NaN   24.0   308
# 40      NaN      NaN      NaN      NaN  ...   742         NaN  175.0   655
# 59      NaN      NaN      NaN      NaN  ...    75         1.0  451.0   597
#
#     female  econ_disadv  disabled  limited_eng        lat        lng
# 4      889          622     185.0        634.0  36.046675 -86.599418
# 13     878          635     190.0        573.0  36.030288 -86.621230
# 35     393          253      55.0          3.0  36.180626 -86.750471
# 40     512          439     104.0        621.0  36.101401 -86.727469
# 59     570          313     165.0         42.0  36.107066 -86.812229
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Now drop the columns named grade_k trhough grade_8 and overwrite you high_schools dataframe with the results

# %%
high_schools = high_schools.drop(columns = ['grade_k', 'grade_1', 'grade_2', 'grade_3', 'grade_4', 'grade_5', 'grade_6', 'grade_8'])

# %%
high_schools.head()
# Out:
#           level                    name  zipcode  grade_7  grade_9  grade_10  \
# 4   High School     Antioch High School    37013      NaN    499.0     486.0
# 13  High School  Cane Ridge High School    37013      NaN    474.0     449.0
# 35  High School   East Nashville School    37206     19.0    153.0     164.0
# 40  High School   Glencliff High School    37211      NaN    349.0     309.0
# 59  High School          Hillsboro High    37215      NaN    314.0     319.0
#
#     grade_11  grade_12  native_amer  asian  ...  hisp  p_islander  white  \
# 4      482.0     448.0          1.0   78.0  ...   806         1.0  387.0
# 13     513.0     422.0          2.0  133.0  ...   655         3.0  313.0
# 35     167.0     175.0          1.0    5.0  ...    13         NaN   24.0
# 40     332.0     177.0          NaN   46.0  ...   742         NaN  175.0
# 59     280.0     252.0          2.0   42.0  ...    75         1.0  451.0
#
#     male  female  econ_disadv  disabled  limited_eng        lat        lng
# 4   1026     889          622     185.0        634.0  36.046675 -86.599418
# 13   980     878          635     190.0        573.0  36.030288 -86.621230
# 35   308     393          253      55.0          3.0  36.180626 -86.750471
# 40   655     512          439     104.0        621.0  36.101401 -86.727469
# 59   597     570          313     165.0         42.0  36.107066 -86.812229
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Create a list name my_zip_codes which contains the zipcodes 37203 and 37013.  Next, use the isin() method to filter the datafrome and save it to itself.

# %%
my_zip_codes = [37203, 37013]

# %%
high_schools = high_schools.loc[high_schools.zipcode.isin(my_zip_codes)]

# %% [markdown]
# ### Rename the level column "high_school"

# %%
high_schools = high_schools.rename(columns = {'level': 'high_school'})
high_schools.head()
# Out:
#     high_school                          name  zipcode  grade_7  grade_9  \
# 4   High School           Antioch High School    37013      NaN    499.0
# 13  High School        Cane Ridge High School    37013      NaN    474.0
# 62  High School                Hume-Fogg High    37203      NaN    231.0
# 98  High School  Martin Luther King Jr School    37203    154.0    266.0
#
#     grade_10  grade_11  grade_12  native_amer  asian  ...  hisp  p_islander  \
# 4      486.0     482.0     448.0          1.0   78.0  ...   806         1.0
# 13     449.0     513.0     422.0          2.0  133.0  ...   655         3.0
# 62     224.0     226.0     220.0          3.0  100.0  ...    68         NaN
# 98     248.0     226.0     230.0          NaN  125.0  ...   111         1.0
#
#     white  male  female  econ_disadv  disabled  limited_eng        lat  \
# 4   387.0  1026     889          622     185.0        634.0  36.046675
# 13  313.0   980     878          635     190.0        573.0  36.030288
# 62  534.0   346     555           60      27.0          8.0  36.159525
# 98  539.0   635     633          129      24.0         23.0  36.161676
#
#           lng
# 4  -86.599418
# 13 -86.621230
# 62 -86.781536
# 98 -86.800474
#
# [4 rows x 21 columns]

# %% [markdown]
# ### Use the shape attribute to see how many rows and columns exist in the current dataframe.

# %%
high_schools.shape
# Out:
# (4, 21)
